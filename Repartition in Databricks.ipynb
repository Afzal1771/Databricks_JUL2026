# %% [markdown]
# #Repartition

# %% [markdown]
# 1. Repartition in Databricks is used to increase or decrease partition in Dataframe.
# 2. It's perform full shuffling of data to distribute it to same partition.
